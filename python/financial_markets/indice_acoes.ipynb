# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI', '^DJI']
ind_data = pd.DataFrame()

for t in tickers:
  ind_data[t] = wb.DataReader(t, data_source='yahoo', start='2015-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                   ^GSPC        ^IXIC       ^GDAXI          ^DJI
# Date
# 2015-01-02  2058.199951  4726.810059  9764.730469  17832.990234
# 2015-01-05  2020.579956  4652.569824  9473.160156  17501.650391
# 2015-01-06  2002.609985  4592.740234  9469.660156  17371.640625
# 2015-01-07  2025.900024  4650.470215  9518.179688  17584.519531
# 2015-01-08  2062.139893  4736.189941  9837.610352  17907.869141

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI          ^DJI
# Date
# 2020-06-09  3207.179932   9953.750000  12617.990234  27272.300781
# 2020-06-10  3190.139893  10020.349609  12530.160156  26989.990234
# 2020-06-11  3002.100098   9492.730469  11970.290039  25128.169922
# 2020-06-12  3041.310059   9588.809570  11949.280273  25605.539062
# 2020-06-15  3066.590088   9726.022461  11911.349609  25763.160156

# %%
(ind_data/ind_data.iloc[0]*100).plot(figsize=(15,6))

# %%
ind_returns = (ind_data/ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI      ^DJI
# Date
# 2020-06-09 -0.007799  0.002922 -0.015726 -0.010885
# 2020-06-10 -0.005313  0.006691 -0.006961 -0.010352
# 2020-06-11 -0.058944 -0.052655 -0.044682 -0.068982
# 2020-06-12  0.013061  0.010121 -0.001755  0.018997
# 2020-06-15  0.008312  0.014310 -0.003174  0.006156

# %%
annual_id_returns = ind_returns.mean()*250
annual_id_returns
# Out:
# ^GSPC     0.090372
# ^IXIC     0.152692
# ^GDAXI    0.055278
# ^DJI      0.086360
# dtype: float64
