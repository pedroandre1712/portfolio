# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['PG', 'BEI.DE']

sec_data= pd.DataFrame()

for t in tickers:
  sec_data[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
sec_data.tail()
# Out:
#                     PG      BEI.DE
# Date
# 2020-06-15  116.690002   96.379997
# 2020-06-16  118.129997   99.900002
# 2020-06-17  117.930000  100.250000
# 2020-06-18  119.279999   99.760002
# 2020-06-19  118.919998  101.250000

# %%
sec_returns = np.log(sec_data/sec_data.shift(1))

# %%
sec_returns
# Out:
#                   PG    BEI.DE
# Date
# 2007-01-03       NaN       NaN
# 2007-01-04 -0.007621  0.006544
# 2007-01-05 -0.008624 -0.020772
# 2007-01-08  0.002202  0.000202
# 2007-01-09 -0.002517 -0.022858
# ...              ...       ...
# 2020-06-15  0.009212 -0.019115
# 2020-06-16  0.012265  0.035871
# 2020-06-17 -0.001694  0.003497
# 2020-06-18  0.011382 -0.004900
# 2020-06-19 -0.003023  0.014825
#
# [3390 rows x 2 columns]

# %%
sec_returns['PG'].mean()
# Out:
# 0.00029915224773705256

# %%
sec_returns['PG'].mean()*250
# Out:
# 0.07478806193426314

# %%
sec_returns['PG'].std()
# Out:
# 0.011965592497531945

# %%
sec_returns['PG'].std()*250**0.5
# Out:
# 0.18919262922811816

# %%
sec_returns['BEI.DE'].mean()
# Out:
# 0.000260295490819062

# %%
sec_returns['BEI.DE'].mean()*250
# Out:
# 0.0650738727047655

# %%
sec_returns['BEI.DE'].std()
# Out:
# 0.013801508704794914

# %%
sec_returns['BEI.DE'].std()*250**0.5
# Out:
# 0.2182210132689619

# %%
print(sec_returns['PG'].mean()*250)
print(sec_returns['BEI.DE'].mean()*250)
# Out:
# 0.07478806193426314
# 0.0650738727047655

# %%
sec_returns[['PG', 'BEI.DE']].mean()*250
# Out:
# PG        0.074788
# BEI.DE    0.065074
# dtype: float64

# %%
sec_returns[['PG', 'BEI.DE']].std()*250**0.5
# Out:
# PG        0.189193
# BEI.DE    0.218221
# dtype: float64

# %% [markdown]
# Agora vamos ver como trabalhar com **variância** e **covariância**

# %%
PG_var = sec_returns['PG'].var()
PG_var
# Out:
# 0.00014317540381699278

# %%
BEI_var = sec_returns['BEI.DE'].var()
BEI_var
# Out:
# 0.00019048164252852978

# %%
PG_var_a = sec_returns['PG'].var()*250
PG_var_a
# Out:
# 0.035793850954248196

# %%
BEI_var_a = sec_returns['BEI.DE'].var()*250
BEI_var_a
# Out:
# 0.047620410632132446

# %%
cov_matrix = sec_returns.cov()
cov_matrix
# Out:
#               PG    BEI.DE
# PG      0.000143  0.000045
# BEI.DE  0.000045  0.000190

# %%
cov_matrix_a = sec_returns.cov()*250
cov_matrix_a
# Out:
#               PG    BEI.DE
# PG      0.035794  0.011371
# BEI.DE  0.011371  0.047620

# %%
corr_matrix = sec_returns.corr()
corr_matrix
# Out:
#               PG    BEI.DE
# PG      1.000000  0.275006
# BEI.DE  0.275006  1.000000
