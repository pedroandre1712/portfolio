# %%
from urllib.request import urlopen
import json

# %%
url = 'http://py4e-data.dr-chuck.net/comments_1478547.json'
resp = urlopen(url)
data = resp.read()
info = json.loads(data)

# %%
data
# Out:
# b'{\n  "note":"This file contains the sample data for testing",\n  "comments":[\n    {\n      "name":"Romina",\n      "count":97\n    },\n    {\n      "name":"Laurie",\n      "count":97\n    },\n    {\n      "name":"Bayli",\n      "count":90\n    },\n    {\n      "name":"Siyona",\n      "count":90\n    },\n    {\n      "name":"Taisha",\n      "count":88\n    },\n    {\n      "name":"Alanda",\n      "count":87\n    },\n    {\n      "name":"Ameelia",\n      "count":87\n    },\n    {\n      "name":"Prasheeta",\n      "count":80\n    },\n    {\n      "name":"Asif",\n      "count":79\n    },\n    {\n      "name":"Risa",\n      "count":79\n    },\n    {\n      "name":"Zi",\n      "count":78\n    },\n    {\n      "name":"Danyil",\n      "count":76\n    },\n    {\n      "name":"Ediomi",\n      "count":76\n    },\n    {\n      "name":"Barry",\n      "count":72\n    },\n    {\n      "name":"Lance",\n      "count":72\n    },\n    {\n      "name":"Hattie",\n      "count":66\n    },\n    {\n     
# ...

# %%
soma = 0
for x in info['comments']:
  soma+= int(x['count'])
soma
# Out:
# 2675

# %%
# Out:
# {'comments': [{'count': 97, 'name': 'Romina'},
#   {'count': 97, 'name': 'Laurie'},
#   {'count': 90, 'name': 'Bayli'},
#   {'count': 90, 'name': 'Siyona'},
#   {'count': 88, 'name': 'Taisha'},
#   {'count': 87, 'name': 'Alanda'},
#   {'count': 87, 'name': 'Ameelia'},
#   {'count': 80, 'name': 'Prasheeta'},
#   {'count': 79, 'name': 'Asif'},
#   {'count': 79, 'name': 'Risa'},
#   {'count': 78, 'name': 'Zi'},
#   {'count': 76, 'name': 'Danyil'},
#   {'count': 76, 'name': 'Ediomi'},
#   {'count': 72, 'name': 'Barry'},
#   {'count': 72, 'name': 'Lance'},
#   {'count': 66, 'name': 'Hattie'},
#   {'count': 66, 'name': 'Mathu'},
#   {'count': 65, 'name': 'Bowie'},
#   {'count': 65, 'name': 'Samara'},
#   {'count': 64, 'name': 'Uchenna'},
#   {'count': 61, 'name': 'Shauni'},
#   {'count': 61, 'name': 'Georgia'},
#   {'count': 59, 'name': 'Rivan'},
#   {'count': 58, 'name': 'Kenan'},
#   {'count': 57, 'name': 'Hassan'},
#   {'count': 57, 'name': 'Isma'},
# ...

# %%
fname = input('Enter file name: ')
if ( len(fname) < 1 ) : fname = 'teste.json'
f = open(fname)
data = json.load(f)
print(data)
# Out:
# Enter file name:
# ...

# %%
for x in data:
    tupla = tuple([valor for valor in x.values()])
    print(len(tupla), tupla)
# Out:
# 7 ('BR 3 (Caeté)', 'Arroz', 'Oryza sativa L.', 'REGISTRADA', '00002', '30/09/1998', 'EMPRESA BRASILEIRA DE PESQUISA AGROPECUÁRIA - EMBRAPA')
# 7 ('CNPA 5M', 'Algodão', 'Gossypium hirsutum L. var. marie galante (Watt) Hutch', 'REGISTRADA', '00007', '30/09/1998', 'EMPRESA BRASILEIRA DE PESQUISA AGROPECUÁRIA - EMBRAPA')
# 7 ('XL 321', 'Milho', 'Zea mays L.', 'REGISTRO CANCELADO POR RENÚNCIA DO MANTENEDOR', '00003', '30/09/1998', 'MONSANTO DO BRASIL LTDA.')
# 7 ('SP70-1143', 'Cana-de-açúcar', 'Saccharum L.', 'REGISTRADA', '00005', '30/09/1998', 'COPERSUCAR')
# 7 ('BR 5102', 'Milho', 'Zea mays L.', 'REGISTRADA', '00004', '30/09/1998', 'EMPRESA BRASILEIRA DE PESQUISA AGROPECUÁRIA - EMBRAPA')
# 7 ('Embrapa 112 (6M)', 'Algodão', 'Gossypium hirsutum L. var. marie galante (Watt) Hutch', 'REGISTRADA', '00006', '30/09/1998', 'EMPRESA BRASILEIRA DE PESQUISA AGROPECUÁRIA - EMBRAPA')
# ...
